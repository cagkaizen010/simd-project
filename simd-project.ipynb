# %% [markdown]
# We originally made this to be compiled and ran using gcc alone.

# %%
# We build NASM locally 

# !wget https://www.nasm.us/pub/nasm/releasebuilds/3.02/nasm-3.02.tar.xz
# !tar -xf nasm-3.02.tar.xz

# %%
# !cd nasm-3.02 && ./configure && make && ./nasm --version
# !rm nasm-3.02.tar.xz # Delete the nasm file after use

# %%
# !./nasm-3.02/nasm --version # Check if nasm is properly installed

# %%
# !make

# %%
# !./main

# %%
# !make clean
